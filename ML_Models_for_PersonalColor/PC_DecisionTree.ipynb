# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
data = pd.read_excel('data2.xlsx', index_col='순번')
data.head()
# Out:
#       H   S   V    R    G    B   l   a   b  계절  봄  여름  가을  겨울  쿨웜
# 순번
# 1     7  11  84  215  194  191  80   7   4   1  1   0   0   0   1
# 2   354  50  85  218  108  119  59  45  15   1  1   0   0   0   1
# 3    11  65  85  218  103   76  58  45  38   1  1   0   0   0   1
# 4     1  65  82  210   76   73  52  54  32   1  1   0   0   0   1
# 5    36  79  83  211  143   44  65  21  60   1  1   0   0   0   1

# %%
feature_names = ['H', 'S', 'V']
dfX = data[feature_names].copy()
dfy = data["쿨웜"].copy()
dfX.tail()
# Out:
#        H   S   V
# 순번
# 715   13  75  85
# 716  264  64  53
# 717  320  75  46
# 718  326  80  66
# 719  341  82  83

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(dfX, dfy, test_size=0.25, random_state=0)


model = DecisionTreeClassifier(
    criterion='entropy', max_depth=3, min_samples_leaf=5).fit(X_train, y_train)

# %%
import io
import pydot
from IPython.core.display import Image
from sklearn.tree import export_graphviz
import graphviz
from sklearn import tree

def draw_decision_tree(model):
    dot_buf = io.StringIO()
    export_graphviz(model, out_file=dot_buf, feature_names=feature_names)
    graph = pydot.graph_from_dot_data(dot_buf.getvalue())[0]
    image = graph.create_png()
    return Image(image)


# def draw_decision_tree(classifier):
#     dot_data = tree.export_graphviz(classifier, out_file=None) 
#     graph = graphviz.Source(dot_data) 
#     graph.render("tree") 

#     dot_data = tree.export_graphviz(classifier, out_file=None, 
#                              feature_names=feature_names,  
#                              class_names=np.array(['쿨웜']),  
#                              filled=True, rounded=True,  
#                              special_characters=True)

#     return graphviz.Source(dot_data) 

model = DecisionTreeClassifier(
    criterion='entropy', max_depth=3, min_samples_leaf=5).fit(X_train, y_train)

draw_decision_tree(model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\GAN\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# ~\anaconda3\envs\GAN\lib\site-packages\pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# ~\anaconda3\envs\GAN\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ~\anaconda3\envs\GAN\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1016                                          os.fspath(cwd) if cwd is not None else None,
# -> 1017                                          startupinfo)
#    1018             finally:
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-3d1b678f9621> in <module>
#      30     criterion='entropy', max_depth=3, min_samples_leaf=5).fit(X_train, y_train)
#      31
# ---> 32 draw_decision_tree(model)
#
# <ipython-input-44-3d1b678f9621> in draw_decision_tree(model)
#      10     export_graphviz(model, out_file=dot_buf, feature_names=feature_names)
#      11     graph = pydot.graph_from_dot_data(dot_buf.getvalue())[0]
# ---> 12     image = graph.create_png()
#      13     return Image(image)
#      14
#
# ~\anaconda3\envs\GAN\lib\site-packages\pydot.py in new_method(f, prog, encoding)
#    1721                 """Refer to docstring of method `create`."""
#    1722                 return self.create(
# -> 1723                     format=f, prog=prog, encoding=encoding)
#    1724             name = 'create_{fmt}'.format(fmt=frmt)
#    1725             self.__setattr__(name, new_method)
#
# ~\anaconda3\envs\GAN\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [WinError 2] "dot" not found in path.

# %%
from sklearn.tree import export_graphviz

# .dot 파일로 export 해줍니다
export_graphviz(model, out_file='tree.dot')

# 생성된 .dot 파일을 .png로 변환
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'decistion-tree.png', '-Gdpi=600'])

# jupyter notebook에서 .png 직접 출력
from IPython.display import Image
Image(filename = 'decistion-tree.png')

export_graphviz(model, 
                out_file='tree.dot',
                feature_names = feature_names,
                class_names = data['쿨웜'],
               )

with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-cbdfde4315fa> in <module>
#       6 # 생성된 .dot 파일을 .png로 변환
#       7 from subprocess import call
# ----> 8 call(['dot', '-Tpng', 'tree.dot', '-o', 'decistion-tree.png', '-Gdpi=600'])
#       9
#      10 # jupyter notebook에서 .png 직접 출력
#
# ~\anaconda3\envs\GAN\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     285     retcode = call(["ls", "-l"])
#     286     """
# --> 287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
#     289             return p.wait(timeout=timeout)
#
# ~\anaconda3\envs\GAN\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     727                                 c2pread, c2pwrite,
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#     731             # Cleanup if the child failed starting.
#
# ~\anaconda3\envs\GAN\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1015                                          env,
#    1016                                          os.fspath(cwd) if cwd is not None else None,
# -> 1017                                          startupinfo)
#    1018             finally:
#    1019                 # Child is launched. Close the parent's copy of those pipe
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다

# %%
# 분류 분석에 사용할 변수 선택
X_ver3 = data[['H', 'S', 'V']] # 독립변수
Y_ver3 = data['쿨웜'] # 종속변수

# 설명변수 데이터 정규화
from sklearn import preprocessing 
X_ver3 = preprocessing.StandardScaler().fit(X_ver3).transform(X_ver3)

# train-test set 데이터 분리
from sklearn.model_selection import train_test_split
X_ver3_train, X_ver3_test, Y_ver3_train, Y_ver3_test = train_test_split(X_ver3, Y_ver3, test_size=0.3, random_state=10)

# Decision Tree 분류 모델 생성
from sklearn import tree
tree_model_ver3 = tree.DecisionTreeClassifier(criterion='entropy', max_depth=13)
tree_model_ver3.fit(X_ver3_train, Y_ver3_train) # 학습시킴

# 예측값 생성
Y_ver3_predict = tree_model_ver3.predict(X_ver3_test)

# 출력
from sklearn import metrics
tree_matrix_ver3 = metrics.confusion_matrix(Y_ver3_test, Y_ver3_predict)
print(tree_matrix_ver3)

tree_report_ver3 = metrics.classification_report(Y_ver3_test, Y_ver3_predict)
print(tree_report_ver3)
# Out:
# [[83 40]
#  [15 78]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.67      0.75       123
#            1       0.66      0.84      0.74        93
#
#     accuracy                           0.75       216
#    macro avg       0.75      0.76      0.75       216
# weighted avg       0.77      0.75      0.75       216
